# %%
import pandas as pd
import numpy as np

# %%
one_bedroom = pd.read_csv('zillow_1bedroom_transformed.csv')
two_bedroom = pd.read_csv('zillow_2bedroom_transformed.csv')
three_bedroom = pd.read_csv('zillow_3bedroom_transformed.csv')
four_bedroom = pd.read_csv('zillow_4bedroom_transformed.csv')
five_bedroom = pd.read_csv('zillow_5bedroom_transformed.csv')

# %%
five_bedroom.head(5)
# Out:
#    Unnamed: 0  RegionID State            County      City  ZipCode  Bedrooms  \
# 0           0     91982    TX  Fort Bend County      Katy    77494         5
# 1           1     61148    NJ      Ocean County  Lakewood     8701         5
# 2           2     91940    TX     Harris County      Katy    77449         5
# 3           3     91733    TX     Harris County   Houston    77084         5
# 4           4     93144    TX    El Paso County   El Paso    79936         5
#
#         2000       2001       2002  ...       2014       2015       2016  \
# 0  293472.87  291307.33  297004.88  ...  430715.46  455776.69  446100.48
# 1  173288.19  195176.95  224392.61  ...  385458.23  433205.58  486038.48
# 2  143394.87  145468.03  149726.36  ...  175390.65  195669.88  207811.60
# 3  143823.34  147133.04  149795.49  ...  197478.13  219470.83  227685.00
# 4  173935.70  169022.94  167233.98  ...  236689.55  239146.54  240302.03
#
# ...

# %%
merged = pd.concat([one_bedroom, two_bedroom, three_bedroom, four_bedroom, five_bedroom], ignore_index=True)

# %%
df = merged.sort_values(['ZipCode', 'Bedrooms'])

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df
# Out:
#        RegionID State                     County       City  ZipCode  \
# 3310      58196    MA             Hampden County     Agawam     1001
# 11639     58196    MA             Hampden County     Agawam     1001
# 27915     58196    MA             Hampden County     Agawam     1001
# 48189     58196    MA             Hampden County     Agawam     1001
# 62426     58196    MA             Hampden County     Agawam     1001
# ...         ...   ...                        ...        ...      ...
# 3489     100478    AK  Ketchikan Gateway Borough  Ketchikan    99901
# 12289    100478    AK  Ketchikan Gateway Borough  Ketchikan    99901
# 28641    100478    AK  Ketchikan Gateway Borough  Ketchikan    99901
# 48872    100478    AK  Ketchikan Gateway Borough  Ketchikan    99901
# 62847    100478    AK  Ketchikan Gateway Borough  Ketchikan    99901
#
#        Bedrooms       2000       2001       2002       2003  ...       2014  \
# ...

# %%
df.to_csv(r'C:\Users\humma\Documents\IT Job\Portfolio Projects\Zillow\transformed_datasets\tables_merged.csv')
