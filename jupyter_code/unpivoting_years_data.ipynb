# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tables_merged.csv')

# %%
df.head(5)
# Out:
#    RegionID State          County    City  ZipCode  Bedrooms       2000  \
# 0     58196    MA  Hampden County  Agawam     1001         1        NaN
# 1     58196    MA  Hampden County  Agawam     1001         2   99469.37
# 2     58196    MA  Hampden County  Agawam     1001         3  131786.40
# 3     58196    MA  Hampden County  Agawam     1001         4  145458.52
# 4     58196    MA  Hampden County  Agawam     1001         5  150549.38
#
#         2001       2002       2003  ...       2014       2015       2016  \
# 0        NaN        NaN        NaN  ...        NaN   65480.93   68650.43
# 1  102201.40  113070.80  124513.17  ...  147774.87  148577.27  153838.93
# 2  136432.58  147627.26  163257.84  ...  200340.74  202733.34  212716.95
# 3  149903.95  162586.51  180017.88  ...  223469.81  226208.94  237877.28
# 4  155917.03  170570.62  189260.07  ...  252689.10  257492.20  270089.33
#
#         2017       2018       2019       2020       2021       2022       2023
# ...

# %% [markdown]
# #### We need to split the original data into smaller tables to query in SQL. As it stands each year is it 's own columns which makes it very difficult ato analyze home prices by year. Specifically here we are unpivoting the dataset so we can get a column called 'Year' whcih can be used for analysis in SQL.

# %%
df.drop(columns=['State', 'County', 'City', 'ZipCode'])
# Out:
#        RegionID  Bedrooms       2000       2001       2002       2003  \
# 0         58196         1        NaN        NaN        NaN        NaN
# 1         58196         2   99469.37  102201.40  113070.80  124513.17
# 2         58196         3  131786.40  136432.58  147627.26  163257.84
# 3         58196         4  145458.52  149903.95  162586.51  180017.88
# 4         58196         5  150549.38  155917.03  170570.62  189260.07
# ...         ...       ...        ...        ...        ...        ...
# 64905    100478         1        NaN        NaN        NaN        NaN
# 64906    100478         2        NaN        NaN        NaN        NaN
# 64907    100478         3        NaN        NaN        NaN        NaN
# 64908    100478         4        NaN        NaN        NaN        NaN
# 64909    100478         5        NaN        NaN        NaN        NaN
#
#             2004       2005       2006       2007  ...       2014       2015  \
# ...

# %%
# Identifying the year columns for unpivoting
year_cols = [str(year) for year in range(2000,2024)]

# Identifier columns are 'RegionID' and 'Bedrooms'
identifier_cols = ['RegionID', 'Bedrooms']

# Using pandas melt to unpivot the data
unpivoted_dataset = pd.melt(df, id_vars = identifier_cols, value_vars = year_cols, var_name = 'Year', value_name = 'Price')

# %%
unpivoted_dataset
# Out:
#          RegionID  Bedrooms  Year      Price
# 0           58196         1  2000        NaN
# 1           58196         2  2000   99469.37
# 2           58196         3  2000  131786.40
# 3           58196         4  2000  145458.52
# 4           58196         5  2000  150549.38
# ...           ...       ...   ...        ...
# 1557835    100478         1  2023  124873.39
# 1557836    100478         2  2023  285527.09
# 1557837    100478         3  2023  413809.57
# 1557838    100478         4  2023  490598.22
# 1557839    100478         5  2023  547036.93
#
# [1557840 rows x 4 columns]

# %%
unpivoted_dataset.to_csv(r'C:\Users\humma\Documents\IT Job\Portfolio Projects\Zillow\transformed_datasets\years_and_price.csv')
